# %%
import sys
# !{sys.executable} -m pip install tracery

# %%
import tracery

# %%
from tracery.modifiers import base_english

# %%
rules = {
    "origin": "#salutation# #desc#\n\n#closings#,\nSun",
    "desc": ["#eyesdesc#", "#smiledesc#", "#breathdesc#", "#hairdesc#"],
    "salutation": ["To", "For"],
    "closings": ["Love", "From", "With love", "Affectionately"],
    
    "recipient_light": ["the light in you", "the gleam in you", "the glow in you"],
    "recipient_smile": ["your #warm_like_adjectives# smile", "your #warm_like_adjectives# grin", "your #warm_like_adjectives# smirk"],
    "recipient_breath": "your morning breath",
    "recipient_hair": ["your #ruffled_synonyms# hair"],
    
    "greeting2": ["dear", "love", "dearest", "beloved"],

    "warm_like_adjectives": ["fuzzy", "warm", "cozy", "snug", "tender", "soft", "infectious", "kind", "winsome"],
    "big_synonyms": ["big", "large", "enormous", "gigantic", "cosmic", "galactic", "astronomical"], 
    "glistening_synonyms": ["glistening", "gleaming", "glittering", "shining", "shimmering", "glowing", "twinkling", "scintillating"],
    "morning_synonyms": ["morning", "daylight", "daybreak", "dawn"],
    "night_synonyms": ["night", "darkness", "dark", "nighttime", "dead of night"],
    "chuckled_synonyms": ["laughed", "giggled", "smiled", "chortled", "cackled"],
    "sunlight_synonyms": ["sunlight", "sun", "sunburst", "daylight", "sunshine"],
    "cold_synonyms": ["cold", "chilly", "icy", "snowy", "crisp", "frosty"],
    "sunset_synonyms": ["sunset", "dusk", "half-light", "evening", "sundown", "nightfall"],
    "ruffled_synonyms": ["ruffled", "messy", "disheveled", "rumpled"],
    "ricocheting_synonyms": ["ricocheting", "bouncing", "caroming", "glancing", "skipping"],
    "tossed_synonyms": ["tossed", "turned", "twisted"],
    "tumbled_synonyms": ["toppled", "skidded", "stumbled", "fell"],
    "divide_synonyms": ["divvy up", "divide", "share", "proportion", "dish out", "split", "measure out"],
    "slumbered_synonyms": ["slumbered", "slept", "rested", "dozed"],
    "warm_feelings": ["warmth", "tenderness", "love", "care", "joy", "sweetness"],
    "sweet_taste_synonyms": ["sweet", "honeyed", "nectarous"],
    "bitter_taste_synonyms": ["bitter", "tarty", "sour"],
    "eye_verbs": ["mirror", "reflect", "embody"],
    "eye_prepositions": ["through", "midst", "amid", "in the thick of", "off", "from"],
    "eye_noun": ["weariness", "exhaustion", "fatigue", "inertia", "torpidity"],
    "fruits": ["strawberries", "raspberries", "blackberries", "cranberries", "bananas", "cherries"],
    "foods": ["beer-washed cheese", "dark chocolate", "peanut butter", "almond butter", "cashew butter"],
    "nature_phrases": ["wet grass", "stiff reed", "clumped seed heads"],
    
    
    "eyesdesc": ["#recipient_light#,\n\nYour eyes, #greeting2#, are so #big_synonyms# in the #morning_synonyms.s#, #glistening_synonyms# #eye_prepositions# the #eye_noun#.\nThey #eye_verbs# the #sunlight_synonyms# #glistening_synonyms# #eye_prepositions# your windowpane."],
    "smiledesc": ["#recipient_smile#,\n\nI’ll #divide_synonyms# the #warm_feelings# I have to give, keeping a #big_synonyms# #divide_synonyms# just for you, even on #cold_synonyms# winter #morning_synonyms.s#.\nYour laughter is the #warm_like_adjectives# glow that lights the streets, #ricocheting_synonyms# from the snow on the sidewalks."],
    "breathdesc": ["#recipient_breath#,\n\nAt #sunset_synonyms#, I had brought you over some #foods#.\nTempered over low flames, dipped into #fruits#, #bitter_taste_synonyms#, and #sweet_taste_synonyms#, at once.\nThe #morning_synonyms# comes by, and now all that I can taste is yesterday’s #warm_feelings#."],
    "hairdesc": ["#recipient_hair#,\n\nWe #tossed_synonyms# and #tossed_synonyms#.\nWe #tumbled_synonyms# down the hill, yet #slumbered_synonyms# through the #night_synonyms#.\nYou woke up with your hair #ruffled_synonyms#, and I put my fingers through it to set it for the day as the #sunlight_synonyms# fell on your face.\nBrushing off the #nature_phrases#.\nWe #chuckled_synonyms# at the end of the hill, and the day broke in."],
}
grammar = tracery.Grammar(rules)
grammar.add_modifiers(base_english)
grammar.flatten("#origin#")
print(grammar.flatten("#origin#"))
# Out:
# For your soft smirk,
#
# I’ll measure out the care I have to give, keeping a astronomical dish out just for you, even on snowy winter daybreaks.
# Your laughter is the fuzzy glow that lights the streets, ricocheting from the snow on the sidewalks.
#
# Love,
# Sun
