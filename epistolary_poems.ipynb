# %%
import sys
# !{sys.executable} -m pip install tracery

# %%
import tracery

# %%
from tracery.modifiers import base_english

# %%
# morning
rules = {
    "origin": "#salutation# #desc#\n\n#closings#,\nSun",
    "desc": ["#eyesdesc#", "#smiledesc#", "#breathdesc#", "#hairdesc#", "#elbowsdesc#", "#sweatsdesc#"],
    "salutation": ["To", "For"],
    "closings": ["Love", "From", "With love", "Affectionately"],
    
    "recipient_light": ["the light in you", "the gleam in you", "the glow in you"],
    "recipient_smile": ["your #warm_like_adjectives# smile", "your #warm_like_adjectives# grin", "your #warm_like_adjectives# smirk"],
    "recipient_breath": "your morning breath",
    "recipient_hair": ["your #ruffled_synonyms# hair"],
    "recipient_elbows": ["your #ashy_synonyms# elbows"],
    "recipient_sweats": ["your night sweats", "your nighttime sweats", "your nocturnal hot flashes"],
    
    "greeting2": ["dear", "love", "dearest", "beloved"],

    "warm_like_adjectives": ["fuzzy", "warm", "cozy", "snug", "tender", "soft", "infectious", "kind", "winsome"],
    "big_synonyms": ["big", "large", "enormous", "gigantic", "cosmic", "galactic", "astronomical"], 
    "glistening_synonyms": ["glistening", "gleaming", "glittering", "shining", "shimmering", "glowing", "twinkling", "scintillating"],
    "morning_synonyms": ["morning", "daylight", "daybreak", "dawn"],
    "night_synonyms": ["night", "darkness", "dark", "nighttime", "dead of night"],
    "chuckled_synonyms": ["laughed", "giggled", "smiled", "chortled", "cackled"],
    "sunlight_synonyms": ["sunlight", "sun", "sunburst", "daylight", "sunshine"],
    "cold_synonyms": ["cold", "chilly", "icy", "snowy", "crisp", "frosty"],
    "sunset_synonyms": ["sunset", "dusk", "half-light", "evening", "sundown", "nightfall"],
    "ruffled_synonyms": ["ruffled", "messy", "disheveled", "rumpled"],
    "ricocheting_synonyms": ["ricocheting", "bouncing", "caroming", "glancing", "skipping"],
    "tossed_synonyms": ["tossed", "turned", "twisted", "swayed", "toppled", "skidded", "stumbled", "fell", "careened"],
    "divide_synonyms": ["divvy up", "divide", "share", "proportion", "dish out", "split", "measure out"],
    "slumbered_synonyms": ["slumbered", "slept", "rested", "dozed"],
    "warm_feelings": ["warmth", "tenderness", "love", "care", "joy", "sweetness"],
    "sweet_taste_synonyms": ["sweet", "honeyed", "nectarous"],
    "skies_synonyms": ["skies", "blues", "horizons", "skylines"],
    "bitter_taste_synonyms": ["bitter", "tarty", "sour"],
    "lotion_synonyms": ["cream", "lotion", "salve"],
    "changes_synonyms": ["transforms", "changes", "metamorphoses", "transposes"],
    "change_synonyms": ["transformation", "change", "metamorphosis", "transposition"],
    "rough_synonyms": ["rough", "coarse", "gritty", "scaly", "rugged", "sandpapery"],
    "ashy_synonyms": ["ashy", "cold", "paled", "pale", "ashen", "pallid"],
    "easier_synonyms": ["easier", "painless", "smooth", "comfortable"],
    "monsooning_synonyms": ["monsooning", "downpouring", "deluging"],
    "offer_synonyms": ["give", "extend", "offer", "trot out"],
    "bend_synonyms": ["bend", "curl", "veer"],
    "reversed_synonyms": ["reversed", "switched", "overturned"],
    "winds_synonyms": ["currents", "gusts", "drafts", "breezes", "blows", "winds"],
    "held_you_tight_phrases": ["held you tight", "held you close", "snoozled into you", "snuggled into you", "nestled into you", "nuzzled into you"],
    "thunder_and_lightning_phrases": ["thunderbolts and roaring", "sparks and growling", "flashes and rumbling", "thunders and lightning"],
    "keeps_changing_phrases": ["keeps changing", "is ephemeral", "is fleeting", "is transient", "is evanescent"],
    "eye_verbs": ["mirror", "reflect", "embody"],
    "eye_prepositions": ["through", "midst", "amid", "in the thick of", "off", "from"],
    "eye_noun": ["weariness", "exhaustion", "fatigue", "inertia", "torpidity"],
    "fruits": ["strawberries", "raspberries", "blackberries", "cranberries", "bananas", "cherries"],
    "foods": ["beer-washed cheese", "dark chocolate", "peanut butter", "almond butter", "cashew butter"],
    "nature_phrases": ["wet grass", "stiff reed", "clumped seed heads"],
    
    
    
    "eyesdesc": ["#recipient_light#,\n\nYour eyes, #greeting2#, are so #big_synonyms# in the #morning_synonyms.s#, #glistening_synonyms# #eye_prepositions# the #eye_noun#.\nThey #eye_verbs# the #sunlight_synonyms# #glistening_synonyms# #eye_prepositions# your windowpane."],
    "smiledesc": ["#recipient_smile#,\n\nI’ll #divide_synonyms# the #warm_feelings# I have to give, keeping a #big_synonyms# #divide_synonyms# just for you, even on #cold_synonyms# winter #morning_synonyms.s#.\nYour laughter is the #warm_like_adjectives# glow that lights the streets, #ricocheting_synonyms# from the snow on the sidewalks."],
    "breathdesc": ["#recipient_breath#,\n\nAt #sunset_synonyms#, I had brought you over some #foods#.\nTempered over low flames, dipped into #fruits#, #bitter_taste_synonyms#, and #sweet_taste_synonyms#, at once.\nThe #morning_synonyms# comes by, and now all that I can taste is yesterday’s #warm_feelings#."],
    "hairdesc": ["#recipient_hair#,\n\nWe #tossed_synonyms# and #tossed_synonyms#.\nWe #tossed_synonyms# down the hill, yet #slumbered_synonyms# through the #night_synonyms#.\nYou woke up with your hair #ruffled_synonyms#, and I put my fingers through it to set it for the day as the #sunlight_synonyms# fell on your face.\nBrushing off the #nature_phrases#.\nWe #chuckled_synonyms# at the end of the hill, and the day broke in."],
    "elbowsdesc": ["#recipient_elbows#,\n\nEvery #morning_synonyms#, the skin #keeps_changing_phrases#. \nWe put #lotion_synonyms# on it to make the #change_synonyms# #easier_synonyms# and less #rough_synonyms#. \nEven though the skin #changes_synonyms#, your elbows will still feel the same each time. \nSo when I #offer_synonyms# my arm to you, will you please #bend_synonyms# your elbow?"],
    "sweatsdesc": ["#recipient_sweats#,\n\nIt was that time of year when the #winds_synonyms# #reversed_synonyms#. \nAt #night_synonyms#, there were #thunder_and_lightning_phrases#, and you were #monsooning_synonyms# over. \nBut I like the rain, so I #held_you_tight_phrases# until it ended. \nNow, it’s a new #morning_synonyms#, and the #skies_synonyms# have become a kaleidoscope of colors and #sunlight_synonyms# showers."]
    
}
grammar = tracery.Grammar(rules)
grammar.add_modifiers(base_english)
grammar.flatten("#origin#")
print(grammar.flatten("#origin#"))
# Out:
# For your soft smirk,
#
# I’ll measure out the tenderness I have to give, keeping a big dish out just for you, even on icy winter mornings.
# Your laughter is the warm glow that lights the streets, glancing from the snow on the sidewalks.
#
# Love,
# Sun

# %%
# night
rules = {
    "origin": "#salutation# #desc#\n\n#closings#,\nSun",
    "desc": ["#yawndesc#", "#dry_handsdesc#", "#pins_and_needles_desc#", 
             "#hypnic_jerk_desc#", "#clenched_teeth_desc#", "#heavy_limbs_desc#"],
    "salutation": ["To", "For"],
    "closings": ["Love", "From", "With love", "Affectionately"],
    
    "recipient_yawn": ["your #yawn_descriptors# yawn"],
    "recipient_dry_hands": ["your #dry_synonyms# hands"],
    "recipient_pins_and_needles": ["the pins and needles"],
    "recipient_hypnic_jerk": ["your #hypnic_synonyms#"],
    "recipient_clenched_teeth": ["your #clenched_synonyms# teeth"],
    "recipient_heavy_limbs": ["your #heavy_synonyms# limbs"],
    
    "greeting2": ["dear", "love", "dearest", "beloved"],

    "warm_like_adjectives": ["fuzzy", "warm", "cozy", "snug", "tender", "soft", "infectious", "kind", "winsome"],
    "yawn_descriptors": ["big", "large", "long", "breathy", "shy", "agonizing", "gaping", "wide", "dainty", "breathy"], 
    "eod_descriptors": ["It’s the end of the day", "The light has begun to wane", "It's the twilight", "It's nighttime", 
                       "It's the night"],
    "hypnic_synonyms": ["hypnic jerks", "sleep twitches", "night starts", "hypnagogic jerks", "myoclonic jerks", "sleep starts"],
    "clenched_synonyms": ["clenched", "tightened", "gripped", "contracted", "clutched", "tensed"],
    "heavy_synonyms": ["heavy", "tired"],
    "dry_synonyms": ["dry", "flaky", "sandpapery", "calloused", "rough"],
    "night_synonyms": ["night", "darkness", "dark", "nighttime"],
    "whisk_yarn_ways": ["Whisk", "Fluff", "Rake through", "Tumble dry"],
    "knit_synonyms": ["knit", "weave", "sew", "stitch"],
    "eye_prepositions": ["through", "midst", "amid", "in the thick of", "off", "from"],
    "tired_synonyms": ["weariness", "exhaustion", "fatigue", "inertia", "torpidity"],
    "slip_synonyms": ["slip", "slide", "skid", "slither", "glide"],
    "house_synonyms": ["roof", "lodge", "house", "home", "cabin", "cottage", "shack"],
    "love_synonyms": ["love", "beloved", "sweet", "honey"],
    "bright_synonyms": ["too bright", "glaring", "blinding", "overbright", "incandescent", "blazing"],
    "river_synonyms": ["river", "stream", "wave"],
    "dried_up_synonyms": ["dried up", "was parched", "drained away", "was bone-dry"],
    "stand_synonyms": ["stand", "sit", "lie", "remain", "wait", "dwell", "wait"],
    "cold_foods": ["ice cream", "gelato", "frozen yogurt", "sorbet"],
    "pain_synonyms": ["pain", "ache", "pang", "sting", "prick", "twinge"],
    "flinch_synonyms": ["flinch", "wince", "squinch"],
    "tingled_synonyms": ["tingled", "clinked", "tinkled", "dinged"],   
    "prickling_synonyms": ["Prickling", "Stinging", "Pricking", "Nagging"],   
    "warm_feelings": ["warmth", "tenderness", "love", "care"],
    "morning_synonyms": ["morning", "daylight", "daybreak", "dawn", "day"],
    "entangled_synonyms": ["entangled", "intertwined", "tangled", "entwined", "intertwisted", "twisted"],
    "soups": ["french onion", "tomato", "lentil", "bean"],
    "carriage_snyonyms": ["carriage", "rail car", "coach"],
    "gnawed_synonyms": ["gnarled", "gnawed"],
    
    
    "yawndesc": ["#recipient_yawn#,\n\n#eod_descriptors#, so I’ll spin you a yarn. \n#whisk_yarn_ways# the yarn to soften it again. \nUnwind the threads, so you open your mouth wide in silence and let the #tired_synonyms# #slip_synonyms# away. \nWatch you, as your eyes close, and the yarn #knit_synonyms.s# into your dreams."],
    "dry_handsdesc": ["#recipient_dry_hands#,\n\nI swam through the #river_synonyms#, #love_synonyms#, by our #house_synonyms#. \nWhen the sun was #bright_synonyms#, I saw the riverbed as the water #dried_up_synonyms#. \nSoon, the rain will fall, and the #river_synonyms# will fill. \nYour hands were hard to hold when the #river_synonyms.s# hit, but I’d rather swim with you than #stand_synonyms# on the empty riverbed."],
    "pins_and_needles_desc": ["#recipient_pins_and_needles#,\n\nAnesthesia spared you the #pain_synonyms#. \nYou didn’t #flinch_synonyms# as they removed your tooth. \nI brought you #cold_foods#, but you couldn’t taste it. \nAt #night_synonyms#, your gums #tingled_synonyms#. \n#prickling_synonyms# more with each hour. \nWhen the sun rises, my #love_synonyms#, you’ll taste the #warm_feelings# in the cold and sweet."],
    "hypnic_jerk_desc": ["#recipient_hypnic_jerk#,\n\nYou were holding onto the pole in the #carriage_snyonyms#. \nMy #love_synonyms#, as the train started to move, your feet shifted, and you gripped the pole tightly. \nEventually, you returned to how you stood before, and you overcame the inertia."],
    "clenched_teeth_desc": ["#recipient_clenched_teeth#,\n\nThe corners of your mouth #pain_synonyms.ed# as you tried to bite into the baguette. \nYesterday, you #gnawed_synonyms# on a rock with your teeth, leaving them weathered. \nBut here’s some #soups# soup that I also made, letting your teeth rest for the night."],
    "heavy_limbs_desc": ["#recipient_heavy_limbs#,\n\nI nuzzled into you as your eyes #slip_synonyms.ed# into the ephemera between #night_synonyms# and #morning_synonyms#, with your legs #entangled_synonyms# with mine. \nYou let the weight you were carrying over from yesterday go. \nIt landed on a mat that was soft, conforming to it, until it couldn’t sink further."]
    
}
grammar = tracery.Grammar(rules)
grammar.add_modifiers(base_english)
grammar.flatten("#origin#")
print(grammar.flatten("#origin#"))
# Out:
# To your heavy limbs,
#
# I nuzzled into you as your eyes glided into the ephemera between night and dawn, with your legs entwined with mine.
# You let the weight you were carrying over from yesterday go.
# It landed on a mat that was soft, conforming to it, until it couldn’t sink further.
#
# Affectionately,
# Sun
